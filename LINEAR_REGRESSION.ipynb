# %% [markdown]
# <a href="https://colab.research.google.com/github/joshimohitm9/Machine-Learning/blob/main/LINEAR_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LinearRegression types
# simple linear regression
# multiple linear regression
# ploynomial regression

# %% [markdown]
# **Linear Regression Single Variable**

# %%
import pandas as pd
import numpy as np

# %%
df={"Area":[2600,3000,3200,3600,4000],
    "Price":[550000,565000,610000,680000,725000]

}

# %%
df=pd.DataFrame(df)

# %%
df
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
x=df[["Area"]]
y=df["Price"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=2)

# %%
X_train
# Out:
#    Area
# 4  4000
# 1  3000
# 3  3600
# 0  2600

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([616465.51724138])

# %%
y_test
# Out:
# 2    610000
# Name: Price, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.plot(X_test,model.predict(X_test))

# %%
model.coef_
# Out:
# array([135.34482759])

# %%
model.intercept_
# Out:
# 183362.06896551716

# %%
# y=mx+c
y=183362.06896551716+4450*135.34482759
y
# Out:
# 785646.551741017

# %%
data = {"area":[2600,3000,3200,3600,4000],
        "bedroom":[2,4,0,3,5],
        "age":[20,15,18,30,8],
        "price":[550000,565000,610000,680000,725000]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    area  bedroom  age   price
# 0  2600        2   20  550000
# 1  3000        4   15  565000
# 2  3200        0   18  610000
# 3  3600        3   30  680000
# 4  4000        5    8  725000

# %%
df["bedroom"][2]=df["bedroom"].median()

# %%
df
# Out:
#    area  bedroom  age   price
# 0  2600        2   20  550000
# 1  3000        4   15  565000
# 2  3200        3   18  610000
# 3  3600        3   30  680000
# 4  4000        5    8  725000

# %%
x=df.drop("price",axis=1)
y=df['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([628897.05882353])

# %%
X_test
# Out:
#    area  bedroom  age
# 2  3200        3   18

# %%
y_test
# Out:
# 2    610000
# Name: price, dtype: int64

# %%
df["area"]
# Out:
# 0    2600
# 1    3000
# 2    3200
# 3    3600
# 4    4000
# Name: area, dtype: int64

# %%
plt.scatter(df["area"],df["price"])

# %%
model.intercept_
# Out:
# 181580.88235294062
